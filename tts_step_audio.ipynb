# %% [markdown]
# <a href="https://colab.research.google.com/github/Harry-Yu-Shuhang/E-Commerce-Final/blob/main/tts_step_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # install

# %%
# !git clone --recursive https://github.com/stepfun-ai/Step-Audio.git
# Out:
# Cloning into 'Step-Audio'...
# remote: Enumerating objects: 682, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 682 (delta 71), reused 48 (delta 46), pack-reused 583 (from 1)
# Receiving objects: 100% (682/682), 21.77 MiB | 11.07 MiB/s, done.
# Resolving deltas: 100% (239/239), done.

# %%
# %cd /content/Step-Audio
# Out:
# /content/Step-Audio

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# !ls /usr/local/cuda-12.5/lib64/libcublasLt*
# Out:
# /usr/local/cuda-12.5/lib64/libcublasLt.so     /usr/local/cuda-12.5/lib64/libcublasLt.so.12.5.3.2
# /usr/local/cuda-12.5/lib64/libcublasLt.so.12  /usr/local/cuda-12.5/lib64/libcublasLt_static.a

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 kB 47.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 20.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 33.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.2/779.2 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 80.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.1/192.1 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 62.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 108.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 701.5/701.5 kB 43.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 74.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 47.4 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Building wheel for sox (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for jaconv (setup.py) ... done
#   Building wheel for oss2 (setup.py) ... done
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Building wheel for crcmod (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.20.1+cu124 requires torch==2.5.1, but you have torch 2.3.1 which is incompatible.

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.3.1
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: filelock, fsspec, jinja2, networkx, nvidia-cublas-cu12, nvidia-cuda-cupti-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-runtime-cu12, nvidia-cudnn-cu12, nvidia-cufft-cu12, nvidia-curand-cu12, nvidia-cusolver-cu12, nvidia-cusparse-cu12, nvidia-nccl-cu12, nvidia-nvtx-cu12, sympy, triton, typing-extensions
# Required-by: accelerate, conformer, fastai, openai-whisper, peft, sentence-transformers, timm, torchaudio, torchvision

# %%
# !pip install torch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1 --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch==2.3.1 in /usr/local/lib/python3.11/dist-packages (2.3.1)
# Collecting torchvision==0.18.1
#   Downloading https://download.pytorch.org/whl/cu121/torchvision-0.18.1%2Bcu121-cp311-cp311-linux_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 94.1 MB/s eta 0:00:00
# Requirement already satisfied: torchaudio==2.3.1 in /usr/local/lib/python3.11/dist-packages (2.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.1) (2.3.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.18.1) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.18.1) (11.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.3.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.3.1) (1.3.0)
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.20.1+cu124
#     Uninstalling torchvision-0.20.1+cu124:
#       Successfully uninstalled torchvision-0.20.1+cu124
# Successfully installed torchvision-0.18.1+cu121

# %%
# !pip install onnxruntime-gpu==1.20.1
# Out:
# Collecting onnxruntime-gpu==1.20.1
#   Downloading onnxruntime_gpu-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu==1.20.1) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu==1.20.1) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu==1.20.1) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu==1.20.1) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu==1.20.1) (5.29.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime-gpu==1.20.1) (1.13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime-gpu==1.20.1) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime-gpu==1.20.1) (1.3.0)
# Downloading onnxruntime_gpu-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (291.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.5/291.5 MB 1.6 MB/s eta 0:00:00
# Installing collected packages: onnxruntime-gpu
#   Attempting uninstall: onnxruntime-gpu
#     Found existing installation: onnxruntime-gpu 1.17.0
#     Uninstalling onnxruntime-gpu-1.17.0:
#       Successfully uninstalled onnxruntime-gpu-1.17.0
# Successfully installed onnxruntime-gpu-1.20.1

# %%
# !pip show onnxruntime-gpu
# Out:
# Name: onnxruntime-gpu
# Version: 1.20.1
# Summary: ONNX Runtime is a runtime accelerator for Machine Learning models
# Home-page: https://onnxruntime.ai
# Author: Microsoft Corporation
# Author-email: onnxruntime@microsoft.com
# License: MIT License
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: coloredlogs, flatbuffers, numpy, packaging, protobuf, sympy
# Required-by:

# %%
# !apt install -y sox
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox3 libwavpack1
# Suggested packages:
#   libsox-fmt-all
# The following NEW packages will be installed:
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa libsox-fmt-base libsox3 libwavpack1 sox
# 0 upgraded, 7 newly installed, 0 to remove and 20 not upgraded.
# Need to get 617 kB of archives.
# After this operation, 1,764 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopencore-amrnb0 amd64 0.1.5-1 [94.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopencore-amrwb0 amd64 0.1.5-1 [49.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsox3 amd64 14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1 [240 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsox-fmt-alsa amd64 14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1 [11.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwavpack1 amd64 5.4.0-1build2 [83.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsox-fmt-base amd64 14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1 [33.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 sox amd64 14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1 [104 kB]
# Fetched 617 kB in 2s (316 kB/s)
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 124926 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../2-libsox3_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../3-libsox-fmt-alsa_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package libwavpack1:amd64.
# Preparing to unpack .../4-libwavpack1_5.4.0-1build2_amd64.deb ...
# Unpacking libwavpack1:amd64 (5.4.0-1build2) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../5-libsox-fmt-base_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../6-sox_14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1_amd64.deb ...
# Unpacking sox (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up libsox3:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up libwavpack1:amd64 (5.4.0-1build2) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Setting up sox (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...

# %% [markdown]
# # download ckpt

# %%
from google.colab import userdata
HF_TOKEN=userdata.get('HF_TOKEN')

# %%
# !huggingface-cli login --token $HF_TOKEN --add-to-git-credential
# Out:
# Token is valid (permission: fineGrained).
# The token `Google Colab` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Google Colab`

# %%
# !huggingface-cli download stepfun-ai/Step-Audio-Tokenizer --quie --local-dir /content/models/stepfun-ai/Step-Audio-Tokenizer
# Out:
# /content/models/stepfun-ai/Step-Audio-Tokenizer

# %%
# !huggingface-cli download stepfun-ai/Step-Audio-TTS-3B --quie --local-dir /content/models/stepfun-ai/Step-Audio-TTS-3B
# Out:
# /content/models/stepfun-ai/Step-Audio-TTS-3B

# %% [markdown]
# # text to speech

# %%
# %cd /content/Step-Audio
# Out:
# /content/Step-Audio

# %%
# tts without ref audio
# !python tts_inference.py --model-path=/content/models/stepfun-ai/ --synthesis-type=tts --output-path=./
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# If you want to use the speaker diarization, please `pip install hdbscan`
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# Please Requires the ffmpeg CLI and `ffmpeg-python` package to be installed.
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
#
# tables:
#
# -----------    ** dataset_classes **    --------------
# | class name   | class location                                                          |
# | AudioDataset | /content/Step-Audio/funasr_detach/datasets/audio_datasets/datasets.py:7 |
# -----------    ** index_ds_classes **    --------------
# | class name            | class location                                                           |
# | IndexDSJsonlRankFull  | /content/Step-Audio/funasr_detach/datasets/audio_datasets/index_ds.py:80 |
# | IndexDSJsonlRankFull  | /content/Step-Audio/funasr_detach/datasets/audio_datasets/index_ds.py:80 |
# | IndexDSJsonlRankSplit | /content/Step-Audio/funasr_detach/datasets/audio_datasets/index_ds.py:12 |
# -----------    ** preprocessor_classes **    --------------
# | class name                   | class location                                                               |
# | SpeechPreprocessSpeedPerturb | /content/Step-Audio/funasr_detach/datasets/audio_datasets/preprocessor.py:18 |
# | TextPreprocessSegDict        | /content/Step-Audio/funasr_detach/datasets/audio_datasets/preprocessor.py:39 |
# -----------    ** batch_sampler_classes **    --------------
# | class name                              | class location                                                            |
# | BatchSampler                            | /content/Step-Audio/funasr_detach/datasets/audio_datasets/samplers.py:9   |
# | RankFullLocalShuffleBatchSampler        | /content/Step-Audio/funasr_detach/datasets/audio_datasets/samplers.py:95  |
# | RankFullLocalShuffleBatchSampler        | /content/Step-Audio/funasr_detach/datasets/audio_datasets/samplers.py:95  |
# | RankFullLocalShuffleDynamicBatchSampler | /content/Step-Audio/funasr_detach/datasets/audio_datasets/samplers.py:199 |
# -----------    ** frontend_classes **    --------------
# | class name        | class location                                                  |
# | WavFrontend       | /content/Step-Audio/funasr_detach/frontends/wav_frontend.py:78  |
# | WavFrontendOnline | /content/Step-Audio/funasr_detach/frontends/wav_frontend.py:211 |
# -----------    ** joint_network_classes **    --------------
# | class name   | class location                                                          |
# | JointNetwork | /content/Step-Audio/funasr_detach/models/transducer/joint_network.py:12 |
# -----------    ** model_classes **    --------------
# | class name             | class location                                                                |
# | BAT                    | /content/Step-Audio/funasr_detach/models/bat/model.py:35                      |
# | BiCifParaformer        | /content/Step-Audio/funasr_detach/models/bicif_paraformer/model.py:37         |
# | Branchformer           | /content/Step-Audio/funasr_detach/models/branchformer/model.py:7              |
# | CAMPPlus               | /content/Step-Audio/funasr_detach/models/campplus/model.py:37                 |
# | CTTransformer          | /content/Step-Audio/funasr_detach/models/ct_transformer/model.py:37           |
# | CTTransformerStreaming | /content/Step-Audio/funasr_detach/models/ct_transformer_streaming/model.py:30 |
# | Conformer              | /content/Step-Audio/funasr_detach/models/conformer/model.py:9                 |
# | ContextualParaformer   | /content/Step-Audio/funasr_detach/models/contextual_paraformer/model.py:43    |
# | EBranchformer          | /content/Step-Audio/funasr_detach/models/e_branchformer/model.py:7            |
# | Emotion2vec            | /content/Step-Audio/funasr_detach/models/emotion2vec/model.py:34              |
# | FsmnVADStreaming       | /content/Step-Audio/funasr_detach/models/fsmn_vad_streaming/model.py:279      |
# | MonotonicAligner       | /content/Step-Audio/funasr_detach/models/monotonic_aligner/model.py:24        |
# | Paraformer             | /content/Step-Audio/funasr_detach/models/paraformer/model.py:26               |
# | ParaformerStreaming    | /content/Step-Audio/funasr_detach/models/paraformer_streaming/model.py:37     |
# | SANM                   | /content/Step-Audio/funasr_detach/models/sanm/model.py:14                     |
# | SCAMA                  | /content/Step-Audio/funasr_detach/models/scama/model.py:39                    |
# | SeacoParaformer        | /content/Step-Audio/funasr_detach/models/seaco_paraformer/model.py:45         |
# | Transducer             | /content/Step-Audio/funasr_detach/models/transducer/model.py:34               |
# | Transformer            | /content/Step-Audio/funasr_detach/models/transformer/model.py:22              |
# | UniASR                 | /content/Step-Audio/funasr_detach/models/uniasr/model.py:26                   |
# | Whisper                | /content/Step-Audio/funasr_detach/models/whisper/model.py:226                 |
# -----------    ** predictor_classes **    --------------
# | class name     | class location                                                                 |
# | CifPredictor   | /content/Step-Audio/funasr_detach/models/paraformer/cif_predictor.py:15        |
# | CifPredictorV2 | /content/Step-Audio/funasr_detach/models/paraformer/cif_predictor.py:191       |
# | CifPredictorV3 | /content/Step-Audio/funasr_detach/models/bicif_paraformer/cif_predictor.py:106 |
# -----------    ** encoder_classes **    --------------
# | class name            | class location                                                                   |
# | AudioEncoder          | /content/Step-Audio/funasr_detach/models/whisper/model.py:146                    |
# | BranchformerEncoder   | /content/Step-Audio/funasr_detach/models/branchformer/encoder.py:296             |
# | ConformerChunkEncoder | /content/Step-Audio/funasr_detach/models/conformer/encoder.py:895                |
# | ConformerEncoder      | /content/Step-Audio/funasr_detach/models/conformer/encoder.py:287                |
# | DFSMN                 | /content/Step-Audio/funasr_detach/models/fsmn_vad_streaming/encoder.py:254       |
# | EBranchformerEncoder  | /content/Step-Audio/funasr_detach/models/e_branchformer/encoder.py:182           |
# | FSMN                  | /content/Step-Audio/funasr_detach/models/fsmn_vad_streaming/encoder.py:180       |
# | RWKVEncoder           | /content/Step-Audio/funasr_detach/models/rwkv_bat/rwkv_encoder.py:16             |
# | SANMEncoder           | /content/Step-Audio/funasr_detach/models/sanm/encoder.py:192                     |
# | SANMEncoderChunkOpt   | /content/Step-Audio/funasr_detach/models/scama/encoder.py:192                    |
# | SANMVadEncoder        | /content/Step-Audio/funasr_detach/models/ct_transformer_streaming/encoder.py:180 |
# | TransformerEncoder    | /content/Step-Audio/funasr_detach/models/transformer/encoder.py:143              |
# -----------    ** decoder_classes **    --------------
# | class name                                 | class location                                                                |
# | ContextualParaformerDecoder                | /content/Step-Audio/funasr_detach/models/contextual_paraformer/decoder.py:119 |
# | DynamicConvolution2DTransformerDecoder     | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:709    |
# | DynamicConvolutionTransformerDecoder       | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:647    |
# | FsmnDecoder                                | /content/Step-Audio/funasr_detach/models/sanm/decoder.py:207                  |
# | FsmnDecoderSCAMAOpt                        | /content/Step-Audio/funasr_detach/models/scama/decoder.py:207                 |
# | LightweightConvolution2DTransformerDecoder | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:585    |
# | LightweightConvolutionTransformerDecoder   | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:523    |
# | ParaformerDecoderSAN                       | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:409    |
# | ParaformerSANDecoder                       | /content/Step-Audio/funasr_detach/models/paraformer/decoder.py:569            |
# | ParaformerSANMDecoder                      | /content/Step-Audio/funasr_detach/models/paraformer/decoder.py:216            |
# | RNNDecoder                                 | /content/Step-Audio/funasr_detach/models/transducer/rnn_decoder.py:87         |
# | RNNTDecoder                                | /content/Step-Audio/funasr_detach/models/transducer/rnnt_decoder.py:14        |
# | TextDecoder                                | /content/Step-Audio/funasr_detach/models/whisper/model.py:180                 |
# | TransformerDecoder                         | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:360    |
# -----------    ** normalize_classes **    --------------
# | class name   | class location                                                        |
# | GlobalMVN    | /content/Step-Audio/funasr_detach/models/normalize/global_mvn.py:12   |
# | UtteranceMVN | /content/Step-Audio/funasr_detach/models/normalize/utterance_mvn.py:9 |
# -----------    ** specaug_classes **    --------------
# | class name | class location                                                  |
# | SpecAug    | /content/Step-Audio/funasr_detach/models/specaug/specaug.py:16  |
# | SpecAugLFR | /content/Step-Audio/funasr_detach/models/specaug/specaug.py:107 |
# -----------    ** tokenizer_classes **    --------------
# | class name              | class location                                                            |
# | CharTokenizer           | /content/Step-Audio/funasr_detach/tokenizer/char_tokenizer.py:12          |
# | SentencepiecesTokenizer | /content/Step-Audio/funasr_detach/tokenizer/sentencepiece_tokenizer.py:12 |
#
#
# ckpt: /content/models/stepfun-ai//Step-Audio-Tokenizer/dengcunqin/speech_paraformer-large_asr_nat-zh-cantonese-en-16k-vocab8501-online/model.pt
# 2025-02-18 12:46:43.036633062 [W:onnxruntime:, transformer_memcpy.cc:74 ApplyImpl] 12 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 2025-02-18 12:46:43.043651089 [W:onnxruntime:, session_state.cc:1168 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# 2025-02-18 12:46:43.043684241 [W:onnxruntime:, session_state.cc:1170 VerifyEachNodeIsAssignedToAnEp] Rerunning with verbose output on a non-minimal build will show node assignments.
# 2025-02-18 12:46:45.706169: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739882806.001833   10200 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739882806.080805   10200 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-18 12:46:46.671266: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-18 12:47:37.805190786 [W:onnxruntime:, transformer_memcpy.cc:74 ApplyImpl] 12 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 2025-02-18 12:47:37.807182619 [W:onnxruntime:, session_state.cc:1168 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# 2025-02-18 12:47:37.807208106 [W:onnxruntime:, session_state.cc:1170 VerifyEachNodeIsAssignedToAnEp] Rerunning with verbose output on a non-minimal build will show node assignments.
# 2025-02-18 12:47:48.290238194 [W:onnxruntime:, transformer_memcpy.cc:74 ApplyImpl] 12 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 2025-02-18 12:47:48.292233203 [W:onnxruntime:, session_state.cc:1168 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# 2025-02-18 12:47:48.292260605 [W:onnxruntime:, session_state.cc:1170 VerifyEachNodeIsAssignedToAnEp] Rerunning with verbose output on a non-minimal build will show node assignments.
# Registered speaker: TingtingRAP
# Registered speaker: Tingting哼唱
# Registered speaker: Tingting

# %%
from IPython.display import Audio
Audio('./output_tts.wav',autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
Audio('examples/prompt_wav_yuqian.wav',autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# tts without ref audio
# !python tts_inference.py --model-path=/content/models/stepfun-ai/ --synthesis-type=clone --output-path=./
# Out:
# If you want to use the speaker diarization, please `pip install hdbscan`
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# Please Requires the ffmpeg CLI and `ffmpeg-python` package to be installed.
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# If you want use mossformer, lease install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
#
# tables:
#
# -----------    ** dataset_classes **    --------------
# | class name   | class location                                                          |
# | AudioDataset | /content/Step-Audio/funasr_detach/datasets/audio_datasets/datasets.py:7 |
# -----------    ** index_ds_classes **    --------------
# | class name            | class location                                                           |
# | IndexDSJsonlRankFull  | /content/Step-Audio/funasr_detach/datasets/audio_datasets/index_ds.py:80 |
# | IndexDSJsonlRankFull  | /content/Step-Audio/funasr_detach/datasets/audio_datasets/index_ds.py:80 |
# | IndexDSJsonlRankSplit | /content/Step-Audio/funasr_detach/datasets/audio_datasets/index_ds.py:12 |
# -----------    ** preprocessor_classes **    --------------
# | class name                   | class location                                                               |
# | SpeechPreprocessSpeedPerturb | /content/Step-Audio/funasr_detach/datasets/audio_datasets/preprocessor.py:18 |
# | TextPreprocessSegDict        | /content/Step-Audio/funasr_detach/datasets/audio_datasets/preprocessor.py:39 |
# -----------    ** batch_sampler_classes **    --------------
# | class name                              | class location                                                            |
# | BatchSampler                            | /content/Step-Audio/funasr_detach/datasets/audio_datasets/samplers.py:9   |
# | RankFullLocalShuffleBatchSampler        | /content/Step-Audio/funasr_detach/datasets/audio_datasets/samplers.py:95  |
# | RankFullLocalShuffleBatchSampler        | /content/Step-Audio/funasr_detach/datasets/audio_datasets/samplers.py:95  |
# | RankFullLocalShuffleDynamicBatchSampler | /content/Step-Audio/funasr_detach/datasets/audio_datasets/samplers.py:199 |
# -----------    ** frontend_classes **    --------------
# | class name        | class location                                                  |
# | WavFrontend       | /content/Step-Audio/funasr_detach/frontends/wav_frontend.py:78  |
# | WavFrontendOnline | /content/Step-Audio/funasr_detach/frontends/wav_frontend.py:211 |
# -----------    ** joint_network_classes **    --------------
# | class name   | class location                                                          |
# | JointNetwork | /content/Step-Audio/funasr_detach/models/transducer/joint_network.py:12 |
# -----------    ** model_classes **    --------------
# | class name             | class location                                                                |
# | BAT                    | /content/Step-Audio/funasr_detach/models/bat/model.py:35                      |
# | BiCifParaformer        | /content/Step-Audio/funasr_detach/models/bicif_paraformer/model.py:37         |
# | Branchformer           | /content/Step-Audio/funasr_detach/models/branchformer/model.py:7              |
# | CAMPPlus               | /content/Step-Audio/funasr_detach/models/campplus/model.py:37                 |
# | CTTransformer          | /content/Step-Audio/funasr_detach/models/ct_transformer/model.py:37           |
# | CTTransformerStreaming | /content/Step-Audio/funasr_detach/models/ct_transformer_streaming/model.py:30 |
# | Conformer              | /content/Step-Audio/funasr_detach/models/conformer/model.py:9                 |
# | ContextualParaformer   | /content/Step-Audio/funasr_detach/models/contextual_paraformer/model.py:43    |
# | EBranchformer          | /content/Step-Audio/funasr_detach/models/e_branchformer/model.py:7            |
# | Emotion2vec            | /content/Step-Audio/funasr_detach/models/emotion2vec/model.py:34              |
# | FsmnVADStreaming       | /content/Step-Audio/funasr_detach/models/fsmn_vad_streaming/model.py:279      |
# | MonotonicAligner       | /content/Step-Audio/funasr_detach/models/monotonic_aligner/model.py:24        |
# | Paraformer             | /content/Step-Audio/funasr_detach/models/paraformer/model.py:26               |
# | ParaformerStreaming    | /content/Step-Audio/funasr_detach/models/paraformer_streaming/model.py:37     |
# | SANM                   | /content/Step-Audio/funasr_detach/models/sanm/model.py:14                     |
# | SCAMA                  | /content/Step-Audio/funasr_detach/models/scama/model.py:39                    |
# | SeacoParaformer        | /content/Step-Audio/funasr_detach/models/seaco_paraformer/model.py:45         |
# | Transducer             | /content/Step-Audio/funasr_detach/models/transducer/model.py:34               |
# | Transformer            | /content/Step-Audio/funasr_detach/models/transformer/model.py:22              |
# | UniASR                 | /content/Step-Audio/funasr_detach/models/uniasr/model.py:26                   |
# | Whisper                | /content/Step-Audio/funasr_detach/models/whisper/model.py:226                 |
# -----------    ** predictor_classes **    --------------
# | class name     | class location                                                                 |
# | CifPredictor   | /content/Step-Audio/funasr_detach/models/paraformer/cif_predictor.py:15        |
# | CifPredictorV2 | /content/Step-Audio/funasr_detach/models/paraformer/cif_predictor.py:191       |
# | CifPredictorV3 | /content/Step-Audio/funasr_detach/models/bicif_paraformer/cif_predictor.py:106 |
# -----------    ** encoder_classes **    --------------
# | class name            | class location                                                                   |
# | AudioEncoder          | /content/Step-Audio/funasr_detach/models/whisper/model.py:146                    |
# | BranchformerEncoder   | /content/Step-Audio/funasr_detach/models/branchformer/encoder.py:296             |
# | ConformerChunkEncoder | /content/Step-Audio/funasr_detach/models/conformer/encoder.py:895                |
# | ConformerEncoder      | /content/Step-Audio/funasr_detach/models/conformer/encoder.py:287                |
# | DFSMN                 | /content/Step-Audio/funasr_detach/models/fsmn_vad_streaming/encoder.py:254       |
# | EBranchformerEncoder  | /content/Step-Audio/funasr_detach/models/e_branchformer/encoder.py:182           |
# | FSMN                  | /content/Step-Audio/funasr_detach/models/fsmn_vad_streaming/encoder.py:180       |
# | RWKVEncoder           | /content/Step-Audio/funasr_detach/models/rwkv_bat/rwkv_encoder.py:16             |
# | SANMEncoder           | /content/Step-Audio/funasr_detach/models/sanm/encoder.py:192                     |
# | SANMEncoderChunkOpt   | /content/Step-Audio/funasr_detach/models/scama/encoder.py:192                    |
# | SANMVadEncoder        | /content/Step-Audio/funasr_detach/models/ct_transformer_streaming/encoder.py:180 |
# | TransformerEncoder    | /content/Step-Audio/funasr_detach/models/transformer/encoder.py:143              |
# -----------    ** decoder_classes **    --------------
# | class name                                 | class location                                                                |
# | ContextualParaformerDecoder                | /content/Step-Audio/funasr_detach/models/contextual_paraformer/decoder.py:119 |
# | DynamicConvolution2DTransformerDecoder     | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:709    |
# | DynamicConvolutionTransformerDecoder       | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:647    |
# | FsmnDecoder                                | /content/Step-Audio/funasr_detach/models/sanm/decoder.py:207                  |
# | FsmnDecoderSCAMAOpt                        | /content/Step-Audio/funasr_detach/models/scama/decoder.py:207                 |
# | LightweightConvolution2DTransformerDecoder | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:585    |
# | LightweightConvolutionTransformerDecoder   | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:523    |
# | ParaformerDecoderSAN                       | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:409    |
# | ParaformerSANDecoder                       | /content/Step-Audio/funasr_detach/models/paraformer/decoder.py:569            |
# | ParaformerSANMDecoder                      | /content/Step-Audio/funasr_detach/models/paraformer/decoder.py:216            |
# | RNNDecoder                                 | /content/Step-Audio/funasr_detach/models/transducer/rnn_decoder.py:87         |
# | RNNTDecoder                                | /content/Step-Audio/funasr_detach/models/transducer/rnnt_decoder.py:14        |
# | TextDecoder                                | /content/Step-Audio/funasr_detach/models/whisper/model.py:180                 |
# | TransformerDecoder                         | /content/Step-Audio/funasr_detach/models/sa_asr/transformer_decoder.py:360    |
# -----------    ** normalize_classes **    --------------
# | class name   | class location                                                        |
# | GlobalMVN    | /content/Step-Audio/funasr_detach/models/normalize/global_mvn.py:12   |
# | UtteranceMVN | /content/Step-Audio/funasr_detach/models/normalize/utterance_mvn.py:9 |
# -----------    ** specaug_classes **    --------------
# | class name | class location                                                  |
# | SpecAug    | /content/Step-Audio/funasr_detach/models/specaug/specaug.py:16  |
# | SpecAugLFR | /content/Step-Audio/funasr_detach/models/specaug/specaug.py:107 |
# -----------    ** tokenizer_classes **    --------------
# | class name              | class location                                                            |
# | CharTokenizer           | /content/Step-Audio/funasr_detach/tokenizer/char_tokenizer.py:12          |
# | SentencepiecesTokenizer | /content/Step-Audio/funasr_detach/tokenizer/sentencepiece_tokenizer.py:12 |
#
#
# ckpt: /content/models/stepfun-ai//Step-Audio-Tokenizer/dengcunqin/speech_paraformer-large_asr_nat-zh-cantonese-en-16k-vocab8501-online/model.pt
# 2025-02-18 12:55:08.957474734 [W:onnxruntime:, transformer_memcpy.cc:74 ApplyImpl] 12 Memcpy nodes are added to the graph main_graph for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 2025-02-18 12:55:08.959561768 [W:onnxruntime:, session_state.cc:1168 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# 2025-02-18 12:55:08.959588266 [W:onnxruntime:, session_state.cc:1170 VerifyEachNodeIsAssignedToAnEp] Rerunning with verbose output on a non-minimal build will show node assignments.
# 2025-02-18 12:55:10.668929: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739883310.697023   12406 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739883310.705797   12406 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-18 12:55:10.751120: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from IPython.display import Audio
Audio('./output_clone.wav',autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-cf38f06b1e45> in <cell line: 0>()
#       1 from IPython.display import Audio
# ----> 2 Audio('./output_clone.wav',autoplay=True)
#
# /usr/local/lib/python3.11/dist-packages/IPython/lib/display.py in __init__(self, data, filename, url, embed, rate, autoplay, normalize, element_id)
#     114         if self.data is not None and not isinstance(self.data, bytes):
#     115             if rate is None:
# --> 116                 raise ValueError("rate must be specified when data is a numpy array or list of audio samples.")
#     117             self.data = Audio._make_wav(data, rate, normalize)
#     118
#
# ValueError: rate must be specified when data is a numpy array or list of audio samples.
